# %%
# !git clone https://github.com/ajinkyakhadilkar/pytorch-cifar-for-EVA.git
# !mv pytorch-cifar-for-EVA pytorch_cifar
# Out:
# Cloning into 'pytorch-cifar-for-EVA'...
# remote: Enumerating objects: 476, done.
# remote: Counting objects: 100% (476/476), done.
# remote: Compressing objects: 100% (224/224), done.
# remote: Total 476 (delta 261), reused 448 (delta 248), pack-reused 0
# Receiving objects: 100% (476/476), 103.07 KiB | 6.06 MiB/s, done.
# Resolving deltas: 100% (261/261), done.

# %%
# !pip install grad-cam
# Out:
# Collecting grad-cam
#   Downloading grad-cam-1.4.8.tar.gz (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 26.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from grad-cam) (1.22.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from grad-cam) (9.4.0)
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from grad-cam) (2.0.1+cu118)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from grad-cam) (0.15.2+cu118)
# Collecting ttach (from grad-cam)
#   Downloading ttach-0.0.3-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from grad-cam) (4.65.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from grad-cam) (4.7.0.72)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from grad-cam) (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from grad-cam) (1.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7.1->grad-cam) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7.1->grad-cam) (16.0.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.8.2->grad-cam) (2.27.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (2.8.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->grad-cam) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->grad-cam) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->grad-cam) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->grad-cam) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7.1->grad-cam) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.8.2->grad-cam) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.8.2->grad-cam) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.8.2->grad-cam) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.8.2->grad-cam) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7.1->grad-cam) (1.3.0)
# Building wheels for collected packages: grad-cam
#   Building wheel for grad-cam (pyproject.toml) ... done
#   Created wheel for grad-cam: filename=grad_cam-1.4.8-py3-none-any.whl size=38247 sha256=3552c92577890039f689d943a36a048fe2ca748c91dc85d422de9840687bf92a
#   Stored in directory: /root/.cache/pip/wheels/f8/04/36/94ff3c8a4215826a21946b34c01180817e606989fdf53f7cd6
# Successfully built grad-cam
# Installing collected packages: ttach, grad-cam
# Successfully installed grad-cam-1.4.8 ttach-0.0.3

# %%
import pytorch_cifar.main as main
import pytorch_cifar.models as models
main.set_net(models.resnet.ResNet18())
# Out:
# ==> Preparing data..
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:05<00:00, 28677798.59it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# ==> Building model..

# %%
from torchsummary import summary

summary(main.net, input_size=(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
#            ResNet-50                   [-1, 10]               0
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %%
main.start_training()
# Out:
# Epoch=0 LR=0.001 Loss=1.632099245515321 batch_id=390 Accuracy=39.14%: 100%|██████████| 391/391 [00:52<00:00,  7.41it/s]
# Test set: Average loss: 1.3593, Accuracy: 4914/10000 (49.14%)
# Epoch=1 LR=0.0009999383162408303 Loss=1.2146372987181329 batch_id=390 Accuracy=55.83%: 100%|██████████| 391/391 [00:41<00:00,  9.31it/s]
# Test set: Average loss: 1.1060, Accuracy: 5994/10000 (59.94%)
# Epoch=2 LR=0.0009997532801828658 Loss=0.9951818283561551 batch_id=390 Accuracy=64.49%: 100%|██████████| 391/391 [00:41<00:00,  9.44it/s]
# Test set: Average loss: 0.9189, Accuracy: 6731/10000 (67.31%)
# Epoch=3 LR=0.0009994449374809851 Loss=0.8645230338091741 batch_id=390 Accuracy=69.13%: 100%|██████████| 391/391 [00:41<00:00,  9.39it/s]
# Test set: Average loss: 1.0197, Accuracy: 6558/10000 (65.58%)
# Epoch=4 LR=0.0009990133642141358 Loss=0.7595655976049126 batch_id=390 Accuracy=73.14%: 100%|██████████| 391/391 [00:41<00:00,  9.45it/s]
# Test set: Average loss: 0.8016, Accuracy: 7260/10000 (72.60%)
# Epoch=5 LR=0.000998458666866564 Loss=0.6747517384531553 batch_id=390 Accuracy=76.21%: 100%|██████████| 391/391 [00:41<00:00,  9.42it/s]
# Test set: Average loss: 0.8235, Accuracy: 7304/10000 (73.04%)
# Epoch=6 LR=0.00099778098230154 Loss=0.612642071207466 batch_id=390 Accuracy=78.57%: 100%|██████████| 391/391 [00:41<00:00,  9.34it/s]
# Test set: Average loss: 0.6827, Accuracy: 7681/10000 (76.81%)
# Epoch=7 LR=0.0009969804777275899 Loss=0.5661536571009994 batch_id=390 Accuracy=80.28%: 100%|██████████| 391/391 [00:41<00:00,  9.41it/s]
# Test set: Average loss: 0.6362, Accuracy: 7886/10000 (78.86%)
# Epoch=8 LR=0.000996057350657239 Loss=0.5248600714042059 batch_id=390 Accuracy=81.50%: 100%|██████████| 391/391 [00:41<00:00,  9.41it/s]
# Test set: Average loss: 0.5570, Accuracy: 8124/10000 (81.24%)
# Epoch=9 LR=0.0009950118288582787 Loss=0.48533150241198136 batch_id=390 Accuracy=83.24%: 100%|██████████| 391/391 [00:42<00:00,  9.30it/s]
# Test set: Average loss: 0.5706, Accuracy: 8076/10000 (80.76%)
# Epoch=10 LR=0.0009938441702975688 Loss=0.45328260039734414 batch_id=390 Accuracy=84.19%: 100%|██████████| 391/391 [00:41<00:00,  9.43it/s]
# Test set: Average loss: 0.5277, Accuracy: 8224/10000 (82.24%)
# Epoch=11 LR=0.000992554663077387 Loss=0.4305724972654182 batch_id=390 Accuracy=85.06%: 100%|██████████| 391/391 [00:41<00:00,  9.42it/s]
# Test set: Average loss: 0.5190, Accuracy: 8265/10000 (82.65%)
# Epoch=12 LR=0.0009911436253643444 Loss=0.40380530890144045 batch_id=390 Accuracy=85.88%: 100%|██████████| 391/391 [00:41<00:00,  9.40it/s]
# Test set: Average loss: 0.5075, Accuracy: 8332/10000 (83.32%)
# Epoch=13 LR=0.0009896114053108828 Loss=0.37623801076656105 batch_id=390 Accuracy=87.03%: 100%|██████████| 391/391 [00:41<00:00,  9.40it/s]
# Test set: Average loss: 0.5070, Accuracy: 8338/10000 (83.38%)
# Epoch=14 LR=0.0009879583809693736 Loss=0.36041376444384876 batch_id=390 Accuracy=87.41%: 100%|██████████| 391/391 [00:41<00:00,  9.32it/s]
# Test set: Average loss: 0.4670, Accuracy: 8443/10000 (84.43%)
# Epoch=15 LR=0.0009861849601988382 Loss=0.3421816279363754 batch_id=390 Accuracy=88.13%: 100%|██████████| 391/391 [00:41<00:00,  9.39it/s]
# Test set: Average loss: 0.5937, Accuracy: 8105/10000 (81.05%)
# Epoch=16 LR=0.0009842915805643154 Loss=0.3227869113311743 batch_id=390 Accuracy=88.59%: 100%|██████████| 391/391 [00:41<00:00,  9.45it/s]
# Test set: Average loss: 0.4744, Accuracy: 8439/10000 (84.39%)
# Epoch=17 LR=0.000982278709228899 Loss=0.3109227567530044 batch_id=390 Accuracy=89.05%: 100%|██████████| 391/391 [00:41<00:00,  9.43it/s]
# Test set: Average loss: 0.4199, Accuracy: 8613/10000 (86.13%)
# Epoch=18 LR=0.0009801468428384714 Loss=0.2910265622617644 batch_id=390 Accuracy=90.09%: 100%|██████████| 391/391 [00:41<00:00,  9.45it/s]
# Test set: Average loss: 0.4185, Accuracy: 8621/10000 (86.21%)
# Epoch=19 LR=0.0009778965073991648 Loss=0.277096936121926 batch_id=390 Accuracy=90.34%: 100%|██████████| 391/391 [00:41<00:00,  9.41it/s]
# Test set: Average loss: 0.4464, Accuracy: 8585/10000 (85.85%)

# %% [markdown]
# # GradCam
#
# Let's test gradcam on one test image.

# %%
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image
import torchvision.transforms as T
from numpy import transpose
import matplotlib.pyplot as plt
import numpy as np

model = main.net
img_iter = iter(main.get_testloader(False))
inp_image = next(img_iter)[0][0].unsqueeze(0)


print(inp_image.size())
target_layers = [model.module.layer3[0].conv1]

cam = GradCAM(model=model, target_layers=target_layers, use_cuda=True)

targets = [ClassifierOutputTarget(9)]

# You can also pass aug_smooth=True and eigen_smooth=True, to apply smoothing.
grayscale_cam = cam(input_tensor=inp_image, targets=targets)

# In this example grayscale_cam has only one image in the batch:
print(grayscale_cam.shape)
grayscale_cam = grayscale_cam[0, :]
rgb_img = (
    inp_image.cpu().squeeze().permute(1,2,0).detach().numpy()
)
print(grayscale_cam.shape)
print(rgb_img.shape)
visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)
#Image.fromarray(visualization).save('s7/output/' + image + "_gradcam.jpeg")

plt.imshow(rgb_img)
# Out:
# Files already downloaded and verified
# torch.Size([1, 3, 32, 32])
# (1, 32, 32)
# (32, 32)
# (32, 32, 3)

# %%
plt.imshow(visualization)

# %%
main.classes[main.net(inp_image).argmax()]
#model(inp_image)
# Out:
# 'ship'

# %%
img_iter = iter(main.get_testloader(True))
inp_image_norm = next(img_iter)[0][0].transpose(0,2)
plt.imshow(inp_image_norm)
model(inp_image)
# Out:
# Files already downloaded and verified
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tensor([[-1.3356, -6.8677,  1.3741,  3.8915,  3.7834,  1.5181,  5.1255, -5.1692,
#           1.2156, -5.1013]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
from pytorch_cifar import utils
mean = [0.485, 0.456, 0.406]
std  = [0.229, 0.224, 0.225]
inv_transform= T.Compose([
    # T.Lambda(lambda x: x.permute(0, 3, 1, 2)),
    T.Normalize(
        mean = (-1 * np.array(mean) / np.array(std)).tolist(),
        std = (1 / np.array(std)).tolist(),
    )])
print(main.misclassified_images[0].transpose(0,2).size())
utils.get_misclassified_images([inv_transform(image).transpose(0,2) for image in main.misclassified_images],
                               main.misclassified_label,
                               main.ground_truth,
                               main.classes)
# Out:
# torch.Size([32, 32, 3])
# Misclassification
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Correct Labels:
# 8 0 6 1 6
#
# 1 0 8 8 4
#
# Prediction :
# 1 8 3 9 2
#
# 9 2 6 9 2
#
# Images

# %%
utils.get_gradcam_of_misclassified_images([image for image in main.misclassified_images],
                               main.misclassified_label,
                               main.ground_truth,
                               main.net,
                               main.classes)
